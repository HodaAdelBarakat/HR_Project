# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load datasets
employee_df = pd.read_csv("/content/Employee.csv")
education_df = pd.read_csv("/content/EducationLevel.csv")
performance_df = pd.read_csv("/content/PerformanceRating.csv")
satisfaction_df = pd.read_csv("/content/SatisfiedLevel.csv")
rating_df = pd.read_csv("/content/RatingLevel.csv")

# %%
# Explore basic info and missing values

# %%
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               1470 non-null   object
#  1   FirstName                1470 non-null   object
#  2   LastName                 1470 non-null   object
#  3   Gender                   1470 non-null   object
#  4   Age                      1470 non-null   int64
#  5   BusinessTravel           1470 non-null   object
#  6   Department               1470 non-null   object
#  7   DistanceFromHome (KM)    1470 non-null   int64
#  8   State                    1470 non-null   object
#  9   Ethnicity                1470 non-null   object
#  10  Education                1470 non-null   int64
#  11  EducationField           1470 non-null   object
#  12  JobRole                  1470 non-null   object
#  13  MaritalStatus            1470 non-null   object
# ...

# %%
employee_df.describe()
# Out:
#                Age  DistanceFromHome (KM)    Education         Salary  \
# count  1470.000000            1470.000000  1470.000000    1470.000000
# mean     28.989796              22.502721     2.912925  112956.497959
# std       7.993055              12.811124     1.024165  103342.889222
# min      18.000000               1.000000     1.000000   20387.000000
# 25%      23.000000              12.000000     2.000000   43580.500000
# 50%      26.000000              22.000000     3.000000   71199.500000
# 75%      34.000000              33.000000     4.000000  142055.750000
# max      51.000000              45.000000     5.000000  547204.000000
#
#        StockOptionLevel  YearsAtCompany  YearsInMostRecentRole  \
# count       1470.000000     1470.000000            1470.000000
# mean           0.793878        4.562585               2.293197
# std            0.852077        3.288048               2.539093
# min            0.000000        0.000000               0.000000
# ...

# %%
employee_df.shape
# Out:
# (1470, 23)

# %%
employee_df.isnull().sum()
# Out:
# EmployeeID                 0
# FirstName                  0
# LastName                   0
# Gender                     0
# Age                        0
# BusinessTravel             0
# Department                 0
# DistanceFromHome (KM)      0
# State                      0
# Ethnicity                  0
# Education                  0
# EducationField             0
# JobRole                    0
# MaritalStatus              0
# Salary                     0
# StockOptionLevel           0
# OverTime                   0
# HireDate                   0
# Attrition                  0
# YearsAtCompany             0
# YearsInMostRecentRole      0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
performance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6709 entries, 0 to 6708
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   PerformanceID                    6709 non-null   object
#  1   EmployeeID                       6709 non-null   object
#  2   ReviewDate                       6709 non-null   object
#  3   EnvironmentSatisfaction          6709 non-null   int64
#  4   JobSatisfaction                  6709 non-null   int64
#  5   RelationshipSatisfaction         6709 non-null   int64
#  6   TrainingOpportunitiesWithinYear  6709 non-null   int64
#  7   TrainingOpportunitiesTaken       6709 non-null   int64
#  8   WorkLifeBalance                  6709 non-null   int64
#  9   SelfRating                       6709 non-null   int64
#  10  ManagerRating                    6709 non-null   int64
# dtypes: int64(8), object(3)
# memory usage: 576.7+ KB

# %%
performance_df.head()
# Out:
#   PerformanceID EmployeeID ReviewDate  EnvironmentSatisfaction  \
# 0          PR01  79F7-78EC   1/2/2013                        5
# 1          PR02  B61E-0F26   1/3/2013                        5
# 2          PR03  F5E3-48BB   1/3/2013                        3
# 3          PR04  0678-748A   1/4/2013                        5
# 4          PR05  541F-3E19   1/4/2013                        5
#
#    JobSatisfaction  RelationshipSatisfaction  TrainingOpportunitiesWithinYear  \
# 0                4                         5                                1
# 1                4                         4                                1
# 2                4                         5                                3
# 3                3                         2                                2
# 4                2                         3                                1
#
#    TrainingOpportunitiesTaken  WorkLifeBalance  SelfRating  ManagerRating
# ...

# %%
performance_df.describe()
# Out:
#        EnvironmentSatisfaction  JobSatisfaction  RelationshipSatisfaction  \
# count              6709.000000      6709.000000               6709.000000
# mean                  3.872559         3.430616                  3.427336
# std                   0.940701         1.152565                  1.156753
# min                   1.000000         1.000000                  1.000000
# 25%                   3.000000         2.000000                  2.000000
# 50%                   4.000000         3.000000                  3.000000
# 75%                   5.000000         4.000000                  4.000000
# max                   5.000000         5.000000                  5.000000
#
#        TrainingOpportunitiesWithinYear  TrainingOpportunitiesTaken  \
# count                      6709.000000                 6709.000000
# mean                          2.012968                    1.017290
# std                           0.820310                    0.950316
# ...

# %%
performance_df.shape
# Out:
# (6709, 11)

# %%
performance_df.isnull().sum()
# Out:
# PerformanceID                      0
# EmployeeID                         0
# ReviewDate                         0
# EnvironmentSatisfaction            0
# JobSatisfaction                    0
# RelationshipSatisfaction           0
# TrainingOpportunitiesWithinYear    0
# TrainingOpportunitiesTaken         0
# WorkLifeBalance                    0
# SelfRating                         0
# ManagerRating                      0
# dtype: int64

# %%
education_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EducationLevelID  5 non-null      int64
#  1   EducationLevel    5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes

# %%
education_df.head()
# Out:
#    EducationLevelID            EducationLevel
# 0                 1  No Formal Qualifications
# 1                 2              High School
# 2                 3                Bachelors
# 3                 4                  Masters
# 4                 5                 Doctorate

# %%
education_df.describe()
# Out:
#        EducationLevelID
# count          5.000000
# mean           3.000000
# std            1.581139
# min            1.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %%
education_df.shape
# Out:
# (5, 2)

# %%
education_df.isnull().sum()
# Out:
# EducationLevelID    0
# EducationLevel      0
# dtype: int64

# %%
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   RatingID     5 non-null      int64
#  1   RatingLevel  5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes

# %%
rating_df.head()
# Out:
#    RatingID           RatingLevel
# 0         1          Unacceptable
# 1         2     Needs Improvement
# 2         3     Meets Expectation
# 3         4  Exceeds Expectation
# 4         5      Above and Beyond

# %%
rating_df.describe()
# Out:
#        RatingID
# count  5.000000
# mean   3.000000
# std    1.581139
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %%
rating_df.shape
# Out:
# (5, 2)

# %%
rating_df.isnull().sum()
# Out:
# RatingID       0
# RatingLevel    0
# dtype: int64

# %%
satisfaction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SatisfactionID     5 non-null      int64
#  1   SatisfactionLevel  5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes

# %%
satisfaction_df.head()
# Out:
#    SatisfactionID  SatisfactionLevel
# 0               1  Very Dissatisfied
# 1               2       Dissatisfied
# 2               3            Neutral
# 3               4         Satisfied
# 4               5     Very Satisfied

# %%
satisfaction_df.describe()
# Out:
#        SatisfactionID
# count        5.000000
# mean         3.000000
# std          1.581139
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000

# %%
satisfaction_df.shape
# Out:
# (5, 2)

# %%
satisfaction_df.isnull().sum()
# Out:
# SatisfactionID       0
# SatisfactionLevel    0
# dtype: int64

# %%
# Remove duplicates from all datasets
employee_df = employee_df.drop_duplicates()

# %%
education_df = education_df.drop_duplicates()

# %%
performance_df = performance_df.drop_duplicates()

# %%
rating_df = rating_df.drop_duplicates()

# %%
satisfaction_df = satisfaction_df.drop_duplicates()

# %%
# Merge the first name and last name rows into the full name row and delete the first two rows
employee_df["FullName"] = employee_df["FirstName"] + " " + employee_df["LastName"]
employee_df.drop(["FirstName", "LastName"], axis=1, inplace=True)

# %%
# Combine first and last name into FullName column
cols = employee_df.columns.tolist()
cols.insert(1, "FullName")
employee_df = employee_df.reindex(columns=cols)

# %%
# Replace education codes with labels
education_df = education_df.rename(columns={"EducationLevelID" : "Education"})
education_map = dict(zip(education_df["Education"], education_df["EducationLevel"]))
employee_df["Education"] = employee_df["Education"].map(education_map)

# %%
education_df['Education'] = education_df['Education'].astype(str)
employee_df = pd.merge(
    employee_df,
    education_df,
    left_on="Education",
    right_on="Education",
    how="left"
)

# %%
# تحويلها إلى DataFrame
rating_df = pd.DataFrame(rating_df)
# تحويلها إلى DataFrame
satisfaction_df = pd.DataFrame(satisfaction_df)
performance_df = pd.DataFrame(performance_df)

# %%
# استخدام map لتحويل EnvironmentSatisfaction إلى SatisfactionLevel
performance_df['EnvironmentSatisfactionLevel'] = performance_df['EnvironmentSatisfaction'].map(satisfaction_df.set_index('SatisfactionID')['SatisfactionLevel'])

# استخدام map لتحويل JobSatisfaction إلى SatisfactionLevel
performance_df['JobSatisfactionLevel'] = performance_df['JobSatisfaction'].map(satisfaction_df.set_index('SatisfactionID')['SatisfactionLevel'])

# استخدام map لتحويل RelationshipSatisfaction إلى SatisfactionLevel
performance_df['RelationshipSatisfactionLevel'] = performance_df['RelationshipSatisfaction'].map(satisfaction_df.set_index('SatisfactionID')['SatisfactionLevel'])

# %%
# تحويل SelfRating إلى RatingLevel باستخدام map
performance_df['SelfRatingLevel'] = performance_df['SelfRating'].map(rating_df.set_index('RatingID')['RatingLevel'])

# تحويل ManagerRating إلى RatingLevel باستخدام map
performance_df['ManagerRatingLevel'] = performance_df['ManagerRating'].map(rating_df.set_index('RatingID')['RatingLevel'])

# %%
# حذف الأعمدة القديمة (SelfRating و ManagerRating)
performance_df.drop(['SelfRating', 'ManagerRating'], axis=1, inplace=True)
performance_df.drop(['JobSatisfaction', 'RelationshipSatisfaction','EnvironmentSatisfaction'], axis=1, inplace=True)
# عرض النتيجة
print(performance_df)
# Out:
#      PerformanceID EmployeeID ReviewDate  TrainingOpportunitiesWithinYear  \
# 0             PR01  79F7-78EC   1/2/2013                                1
# 1             PR02  B61E-0F26   1/3/2013                                1
# 2             PR03  F5E3-48BB   1/3/2013                                3
# 3             PR04  0678-748A   1/4/2013                                2
# 4             PR05  541F-3E19   1/4/2013                                1
# ...            ...        ...        ...                              ...
# 6704         PR995  4F28-CFAF  3/14/2016                                3
# 6705         PR996  7C80-94E0  3/14/2016                                2
# 6706         PR997  8233-2483  3/14/2016                                3
# 6707         PR998  8A5B-3D6E  3/15/2016                                2
# 6708         PR999  4500-37EB  3/16/2016                                3
#
#       TrainingOpportunitiesTaken  WorkLifeBalance  \
# ...

# %%
employee_df.sample(10)
# Out:
#      EmployeeID          FullName      Gender  Age      BusinessTravel  \
# 814   DBF5-E57D  Freeland Chalcot        Male   25         Some Travel
# 502   B102-5713      Adlai Pettit  Non-Binary   27         Some Travel
# 890   7A2A-0600   Axel McIlhatton        Male   24  Frequent Traveller
# 641   566A-FC64      Loria Pursey      Female   27         Some Travel
# 1242  BC21-2167      Aldin Barens  Non-Binary   28  Frequent Traveller
# 508   AC19-7EE7      Aube Bassill        Male   25         Some Travel
# 763   FB4B-067E   Adan Sunderland      Female   31         Some Travel
# 619   28EA-A010      Meara Mahony      Female   26         Some Travel
# 85    AEDB-BB62    Munmro Ledamun        Male   39         Some Travel
# 206   45D2-369E   Melvin McGeneay        Male   30         Some Travel
#
#       Department  DistanceFromHome (KM) State  \
# 814   Technology                     25    CA
# 502        Sales                     31    CA
# ...

# %%
performance_df.sample(10)
# Out:
#      PerformanceID EmployeeID  ReviewDate  TrainingOpportunitiesWithinYear  \
# 5366        PR5825  4A0E-9958   3/10/2022                                2
# 5321        PR5785  EACC-D1F6    3/1/2022                                2
# 3363        PR4020  6313-8E62   5/30/2020                                1
# 861         PR1767  A2B5-823F   7/10/2017                                2
# 5910        PR6315  BFE7-5EA8    8/5/2022                                2
# 5727        PR6150  648E-FE5F   6/13/2022                                2
# 4310        PR4874  10E9-4C86   4/16/2021                                2
# 2772        PR3489  C22D-CE5F  11/24/2019                                1
# 6348         PR671  A2D0-E2D2   5/20/2015                                3
# 57          PR1042  1A7C-19DB   4/11/2016                                3
#
#       TrainingOpportunitiesTaken  WorkLifeBalance  \
# 5366                           1                3
# ...

# %%
# General metrics

# %%
total_employees = employee_df['EmployeeID'].nunique()
print(total_employees)
# Out:
# 1470

# %%
gender_count = employee_df['Gender'].value_counts()
print(gender_count)
# Out:
# Gender
# Female               675
# Male                 651
# Non-Binary           124
# Prefer Not To Say     20
# Name: count, dtype: int64

# %%
avg_age = employee_df['Age'].mean()
print(avg_age)
# Out:
# 28.989795918367346

# %%
sns.histplot(employee_df["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
avg_salary = employee_df['Salary'].mean()
print(avg_salary)
# Out:
# 112956.49795918367

# %%
attrition_rate = employee_df['Attrition'].value_counts(normalize=True).get('Yes', 0) * 100
print(attrition_rate)
# Out:
# 16.122448979591837

# %%
num_departments = employee_df['Department'].nunique()
print(num_departments)
# Out:
# 3

# %%
avg_years = employee_df['YearsAtCompany'].mean()
print(avg_years)
# Out:
# 4.562585034013606

# %%
avg_training = performance_df['TrainingOpportunitiesTaken'].mean()
print(avg_training)
# Out:
# 1.0172902071843792

# %%
avg_distance = employee_df['DistanceFromHome (KM)'].mean()
print(avg_distance)
# Out:
# 22.502721088435376

# %%
avg_years_at_company = employee_df['YearsAtCompany'].mean()
print(avg_years_at_company)
# Out:
# 4.562585034013606

# %%
total_employees = len(employee_df)
print(total_employees)
# Out:
# 1470

# %%
gender_count = employee_df['Gender'].value_counts()
print(gender_count)
# Out:
# Gender
# Female               675
# Male                 651
# Non-Binary           124
# Prefer Not To Say     20
# Name: count, dtype: int64

# %%
employees_left = employee_df[employee_df["Attrition"] == "Yes"].shape[0]
print(employees_left)
# Out:
# 237

# %%
attrition_counts = employee_df["Attrition"].value_counts()
print(attrition_counts)
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
# Visualizations

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=employee_df, x='Gender', palette='Reds')
plt.title('Gender Distribution')
plt.show()
# Out:
# <ipython-input-231-89a5379bf08f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=employee_df, x='Gender', palette='Reds')

# %%
#Q1: What is the employee turnover rate and which factors influence it?
# --- Part 1: Calculate the turnover rate ---
turnover_rate = employee_df['Attrition'].value_counts(normalize=True).get('Yes', 0) * 100
print(f" Employee Turnover Rate: {turnover_rate:.2f}%")

# --- Part 2: Correlation between potential influencing factors ---
# Select relevant features (demographic, financial, job-related)
factors_df = merged_df[[
    'Age',
    'Salary',
    'YearsAtCompany',
    'YearsSinceLastPromotion',
    'YearsWithCurrManager']]

# Calculate and print the correlation matrix
print("Correlation between influencing factors:")
print(factors_df.corr())
# Out:
#  Employee Turnover Rate: 16.12%
# Correlation between influencing factors:
#                               Age    Salary  YearsAtCompany  \
# Age                      1.000000  0.424894        0.642532
# Salary                   0.424894  1.000000        0.212381
# YearsAtCompany           0.642532  0.212381        1.000000
# YearsSinceLastPromotion  0.546807  0.162546        0.848310
# YearsWithCurrManager     0.452875  0.118997        0.657974
#
#                          YearsSinceLastPromotion  YearsWithCurrManager
# Age                                     0.546807              0.452875
# Salary                                  0.162546              0.118997
# YearsAtCompany                          0.848310              0.657974
# YearsSinceLastPromotion                 1.000000              0.558008
# YearsWithCurrManager                    0.558008              1.000000

# %%
#Q1: What is the employee turnover rate in the company, and which factors influence it?
attrition_counts = employee_df["Attrition"].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(attrition_counts, labels = ["Still in the company", "Left the company"], autopct='%1.1f%%', colors = ["#1f77b4", "#ff7f0e"], startangle=90, wedgeprops={"edgecolor": "black"})
plt.title("Employee Turnover Rate")
plt.show()

# %%
#Q2: Which departments and job roles are most affected by employee turnover, and what factors contribute to this trend?
#  Turnover count by Department and Job Role (only for employees who left)
turnover_by_dept_role = employee_df[employee_df['Attrition'] == 'Yes'] \
    .groupby(['Department', 'JobRole']).size() \
    .sort_values(ascending=False)

print(" Employee Turnover by Department and Job Role:")
print(turnover_by_dept_role)
# Out:
#  Employee Turnover by Department and Job Role:
# Department       JobRole
# Technology       Data Scientist               62
# Sales            Sales Executive              57
# Technology       Software Engineer            47
# Sales            Sales Representative         33
# Technology       Machine Learning Engineer    10
# Human Resources  Recruiter                     9
# Technology       Senior Software Engineer      9
#                  Analytics Manager             3
# Human Resources  HR Executive                  3
# Sales            Manager                       2
# Technology       Engineering Manager           2
# dtype: int64

# %%
#Q3: How do salaries vary across departments, job roles, and demographic factors such as age, gender, and experience?
#How do salaries vary across departments?
plt.figure(figsize=(10, 5))
sns.boxplot(x="Department", y="Salary", data=employee_df, palette="Set2")
plt.xticks(rotation=45)
plt.title("Salary Distribution by Department")
plt.show()
# Out:
# <ipython-input-235-e8dab24afae3>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Department", y="Salary", data=employee_df, palette="Set2")

# %%
#Q3: How do salaries vary across departments, job roles, and demographic factors such as age, gender, and experience?
#How do salaries vary across job roles?
plt.figure(figsize=(12, 5))
sns.boxplot(x="JobRole", y="Salary", data=employee_df, palette="coolwarm")
plt.xticks(rotation=90)
plt.title("Salary Distribution by Job Role")
plt.show()
# Out:
# <ipython-input-236-45f626de90a4>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="JobRole", y="Salary", data=employee_df, palette="coolwarm")

# %%
#Q3: How do salaries vary across departments, job roles, and demographic factors such as age, gender, and experience?
#How do salaries vary with experience?
plt.figure(figsize=(8, 5))
sns.regplot(x="YearsAtCompany", y="Salary", data=employee_df, scatter_kws={"alpha":0.5})
plt.title("Effect of Years of Experience on Salary")
plt.show()

# %%
#Q3: How do salaries vary across departments, job roles, and demographic factors such as age, gender, and experience?
#How do salaries vary with age?
plt.figure(figsize=(10, 5))
sns.regplot(x="YearsAtCompany", y="Salary", data=employee_df, scatter_kws={"alpha": 0.5}, line_kws={"color": "red"})
plt.title("Effect of Years of Experience on Salary", fontsize=14, fontweight='bold')
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
#Q3: How do salaries vary across departments, job roles, and demographic factors such as age, gender, and experience?
#"How do salaries vary across gender?
plt.figure(figsize=(8, 5))
sns.boxplot(x="Gender", y="Salary", data=employee_df, palette="pastel")
plt.title("Salary Comparison by Gender", fontsize=14, fontweight='bold')
plt.xlabel("Gender")
plt.ylabel("Salary")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()
# Out:
# <ipython-input-239-6eb49108c5b5>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Gender", y="Salary", data=employee_df, palette="pastel")

# %%
#Q4. How will the average salary in the company change over the next year?
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = employee_df[['Age', 'YearsAtCompany']]
y = employee_df['Salary']
model = LinearRegression().fit(X, y)

future_data = X.copy()
future_data['YearsAtCompany'] += 1
employee_df['PredictedSalaryNextYear'] = model.predict(future_data)

current_avg_salary = employee_df['Salary'].mean()
predicted_avg_salary = employee_df['PredictedSalaryNextYear'].mean()

print(f"Current Average Salary: ${current_avg_salary:.2f}")
print(f"Predicted Average Salary Next Year: ${predicted_avg_salary:.2f}")
# Out:
# Current Average Salary: $112956.50
# Predicted Average Salary Next Year: $104872.80

# %%
# Q5:How has the number of employees hired in each department changed over the years?
# تحويل HireDate إلى datetime لو مش متحول بالفعل
employee_df['HireDate'] = pd.to_datetime(employee_df['HireDate'])

# استخراج سنة التوظيف
employee_df['HireYear'] = employee_df['HireDate'].dt.year
# حساب عدد التوظيفات لكل قسم في كل سنة
hire_trend = employee_df.groupby(['HireYear', 'Department']).size().reset_index(name='Hires')

# رسم الترند
plt.figure(figsize=(12, 6))
sns.lineplot(data=hire_trend, x='HireYear', y='Hires', hue='Department', marker='o')
plt.title('Hiring Trend by Department')
plt.ylabel('Number of Hires')
plt.xlabel('Year')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# Q5: How many employees are expected to be hired in each department next year?
# توقع عدد الموظفين اللي هيتوظفوا السنة الجاية باستخدام Linear Regression لكل قسم

from sklearn.linear_model import LinearRegression

future_hiring = {}

for dept in hire_trend['Department'].unique():
    dept_data = hire_trend[hire_trend['Department'] == dept]
    X = dept_data[['HireYear']]
    y = dept_data['Hires']

    model = LinearRegression().fit(X, y)
    next_year = [[employee_df['HireYear'].max() + 1]]
    prediction = model.predict(next_year)[0]

    future_hiring[dept] = int(round(prediction))

print("Expected hires next year per department:")
for dept, hires in future_hiring.items():
    print(f"{dept}: {hires} hires")
# Out:
# Expected hires next year per department:
# Human Resources: 6 hires
# Sales: 41 hires
# Technology: 90 hires
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Q6: Which factors (education level, financial benefits, managerial level, years of experience) have the strongest impact on salaries and promotions?
# Selecting relevant numeric columns for analysis
df_q7 = merged_df[[
    'Salary',
    'Education',
    'YearsAtCompany',
    'YearsInMostRecentRole',
    'YearsSinceLastPromotion',
    'YearsWithCurrManager']]

# Convert 'Education' to numeric representation using Label Encoding
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df_q7['Education'] = encoder.fit_transform(df_q7['Education'])

# Compute the correlation matrix
correlation_matrix = df_q7.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation between Salary and Other Career Factors', fontsize=14)
plt.tight_layout()
plt.show()

# Print sorted correlation values for Salary
print("Factors most correlated with Salary:")
print(correlation_matrix['Salary'].sort_values(ascending=False))
# Out:
# <ipython-input-245-f4e62dc28e0d>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_q7['Education'] = encoder.fit_transform(df_q7['Education'])
# Factors most correlated with Salary:
# Salary                     1.000000
# YearsAtCompany             0.212381
# YearsSinceLastPromotion    0.162546
# YearsWithCurrManager       0.118997
# YearsInMostRecentRole      0.109305
# Education                 -0.066146
# Name: Salary, dtype: float64

# %%
# Q7: How do work-life balance and frequent travel impact employee satisfaction and retention?
#Filter relevant columns
df_q8 = merged_df[['BusinessTravel', 'WorkLifeBalance', 'JobSatisfaction', 'Attrition']]

sns.set_theme(style="whitegrid")

# Create two subplots: One for satisfaction, one for attrition
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# --- Plot 1: Work-Life Balance vs Job Satisfaction ---
sns.boxplot(x='WorkLifeBalance',
            y='JobSatisfaction',
            data=df_q8,
            palette="coolwarm",
            ax=axes[0])
axes[0].set_title('Job Satisfaction vs Work-Life Balance', fontsize=13)
axes[0].set_xlabel('Work-Life Balance (1 = Bad, 5 = Excellent)')
axes[0].set_ylabel('Job Satisfaction')

# --- Plot 2: Business Travel vs Attrition ---
sns.countplot(x='BusinessTravel',
              hue='Attrition',
              data=df_q8,
              palette="Set2",
              ax=axes[1])
axes[1].set_title('Attrition vs Business Travel', fontsize=13)
axes[1].set_xlabel('Business Travel Frequency')
axes[1].set_ylabel('Number of Employees')
axes[1].tick_params(axis='x', rotation=15)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-246-557a805f7b3a>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='WorkLifeBalance',

# %%
# Question 8: How does the number of years with the same manager affect employee satisfaction and retention?

sns.set_theme(style="whitegrid")

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# --- Plot 1: Boxplot - Years with Manager vs Job Satisfaction ---
sns.boxplot(x='JobSatisfaction', y='YearsWithCurrManager',
            data=merged_df, palette="pastel", ax=axes[0])
axes[0].set_title('Years with Current Manager vs Job Satisfaction', fontsize=13)
axes[0].set_xlabel('Job Satisfaction')
axes[0].set_ylabel('Years with Current Manager')

# --- Plot 2: Stacked Histogram - Attrition vs Years with Manager ---
sns.histplot(data=merged_df,
             x='YearsWithCurrManager',
             hue='Attrition',
             multiple='stack',
             bins=15,
             palette='Set2',
             ax=axes[1])
axes[1].set_title('Attrition vs Years with Current Manager', fontsize=13)
axes[1].set_xlabel('Years with Manager')
axes[1].set_ylabel('Number of Employees')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-247-d5eace975c67>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='JobSatisfaction', y='YearsWithCurrManager',

# %%
#Question 9: How realistic is the gap between employees' self-ratings and manager ratings?
rating_comparison = performance_df[['SelfRatingLevel', 'ManagerRatingLevel']].copy()

comparison_table = pd.crosstab(rating_comparison['SelfRatingLevel'],
                               rating_comparison['ManagerRatingLevel'])

print("Self vs Manager Rating Comparison Table:")
print(comparison_table)

plt.figure(figsize=(10,6))
sns.heatmap(comparison_table, annot=True, fmt="d", cmap="YlGnBu")
plt.title("Self Rating vs Manager Rating")
plt.xlabel("Manager Rating")
plt.ylabel("Self Rating")
plt.tight_layout()
plt.show()
# Out:
# Self vs Manager Rating Comparison Table:
# ManagerRatingLevel    Above and Beyond  Exceeds Expectation   \
# SelfRatingLevel
# Above and Beyond                  1074                  1109
# Exceeds Expectation                  0                  1110
# Meets Expectation                    0                     1
#
# ManagerRatingLevel    Meets Expectation  Needs Improvement
# SelfRatingLevel
# Above and Beyond                      0                  0
# Exceeds Expectation                1126                  0
# Meets Expectation                  1097               1192

# %%
#Question 10: What is the impact of training opportunities on employee satisfaction and career growth?
#What is the impact of training on job satisfaction?
plt.figure(figsize=(8,5))
# Use merged_df instead of performance_df, since 'JobSatisfaction' is in merged_df
sns.boxplot(x='TrainingOpportunitiesWithinYear', y='JobSatisfaction', data=merged_df)
plt.title('Job Satisfaction vs Training Opportunities (Within Year)')
plt.tight_layout()
plt.show()

#What is the impact of training on career growth?
sns.scatterplot(x='TrainingOpportunitiesTaken', y='YearsSinceLastPromotion',  data=merged_df)
plt.title('Training Taken vs Years Since Last Promotion')
plt.tight_layout()
plt.show()
